# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
l1=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name='1S 1X',header=[3])

# %%
l2=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name=' 1S 2X',header=[3])

# %%
l3=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name='1S 3AX',header=[3])

# %%
l4=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name=' 1S 4X',header=[3])

# %%
l5=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name='1S 5X',header=[3])

# %%
l1.drop([0], inplace=True)

# %%
l1.replace(-999.25,np.nan,inplace=True)

# %%
l1=l1.dropna()

# %%
l1
# Out:
#            DEPTH     CALI        GR     ILD     ITT     LLD     LLS    MSFL  \
# 9401   1524.0000  14.4538   54.8415  0.9607  0.1233  0.9879  1.0776  1.4853
# 9402   1524.1524  14.0887   55.8918  0.9660  0.1231  0.9906  1.0821  1.5206
# 9403   1524.3048  13.8190   57.2492  0.9624  0.1238  0.9823  1.0876  1.4323
# 9404   1524.4572  13.7363   58.0199  0.9399  0.1252  0.9660  1.0079  1.3148
# 9405   1524.6096  13.8716   58.2939  0.9146  0.1256  0.9360  1.0188  1.2740
# ...          ...      ...       ...     ...     ...     ...     ...     ...
# 23253  3635.0448   9.3138  115.5579  2.1824  0.0854  2.1704  2.5690  3.1694
# 23254  3635.1972   9.1831  115.3115  2.2141  0.0859  2.1827  2.5769  2.8899
# 23255  3635.3496   8.9994  114.8351  2.2159  0.0865  2.1733  2.5695  1.2580
# 23256  3635.5020   8.9888  115.0071  2.1779  0.0863  2.1579  2.5616  0.7530
# 23257  3635.6544   8.9945  116.4589  2.1265  0.0856  2.1191  2.5447  0.8664
#
#          NPHI    RHOB     SFL       SP
# ...

# %%
l2.drop([0,1,2],inplace=True)

# %%
l2.replace(-999.25,np.nan, inplace=True)

# %%
l2=l2.dropna()

# %%
l2
# Out:
#            DEPTH     CALI        GR     ILD     ITT     LLD     LLS    MSFL  \
# 9583   1581.9120  14.6117   72.3413  0.9733  0.1365  0.8844  1.0454  0.8075
# 9584   1582.0644  15.1402   71.4789  0.9894  0.1349  0.9197  1.0387  0.6889
# 9585   1582.2168  15.1520   71.2632  1.0084  0.1336  0.9416  1.0216  0.6483
# 9586   1582.3692  14.8484   69.6416  1.0274  0.1324  0.9429  0.9988  0.6234
# 9587   1582.5216  15.4542   68.1555  1.0387  0.1306  0.9288  0.9763  0.7767
# ...          ...      ...       ...     ...     ...     ...     ...     ...
# 20899  3306.4704  12.6247  106.5361  2.5241  0.0870  1.9885  2.3306  2.9424
# 20900  3306.6228  12.6271  104.1838  2.4460  0.0870  2.0045  2.3176  2.9974
# 20901  3306.7752  12.6282  110.7324  2.3721  0.0870  2.0225  2.3032  3.0224
# 20902  3306.9276  12.6273  115.5901  2.3395  0.0871  2.0349  2.2898  3.0355
# 20903  3307.0800  12.6269  118.2560  2.2852  0.0871  2.0428  2.2882  3.0393
#
#          NPHI    RHOB     SFL       SP
# ...

# %%
l3.replace(-999.25,np.nan,inplace=True)

# %%
l3.dropna(inplace=True)

# %%
l3
# Out:
#            DEPTH     CALI       GR     ILD     ITT     LLD     LLS    MSFL  \
# 9763     1615.44  15.2401  59.0503  0.9317  0.1323  0.9221  1.0336   1.183
# 9764   1615.5924   15.231  57.2185  0.9513  0.1321  0.9044  1.0357  1.1894
# 9765   1615.7448  15.1242  55.8582   0.971  0.1319   0.893  1.0343   1.198
# 9766   1615.8972  14.9753  55.9452  0.9793   0.132  0.8849  1.0286   1.204
# 9767   1616.0496  14.8822  56.3107  0.9858  0.1325  0.8824  1.0108  1.2096
# ...          ...      ...      ...     ...     ...     ...     ...     ...
# 17075  2729.7888  12.2535  85.9298  1.8382  0.0931  2.2281  2.6699  0.5899
# 17076  2729.9412  12.2412  85.4963  1.8557  0.0938  2.2328  2.6854  0.5421
# 17077  2730.0936  12.2509  86.1886  1.8716  0.0944  2.2375  2.6957  0.4983
# 17078   2730.246  12.2523  86.9371  1.8809  0.0947  2.2525   2.706  0.4652
# 17079  2730.3984  12.2481   85.392  1.8809  0.0948  2.2681  2.7164  0.4751
#
#          NPHI    RHOB     SFL       SP
# ...

# %%
l4.replace(-999.25,np.nan,inplace=True)
l4.dropna(inplace=True)

# %%
l4
# Out:
#            DEPTH     CALI       GR     ILD     ITT     LLD     LLS    MSFL  \
# 8533   1397.8128  13.0089  48.6938  4.8681  0.0394  1.3742  1.1744  0.3199
# 8534   1397.9652  13.4357  50.5618  1.6163  0.0883  1.3631   1.179  0.3188
# 8535   1398.1176  17.8938   53.313  2.0106  0.1045  1.3652  1.1826  0.3178
# 8536     1398.27  19.2379  55.1094  2.9638  0.1025  1.3925  1.1641  0.3188
# 8537   1398.4224  20.3908  54.8873  3.5034  0.1027  1.3968   1.131  0.3179
# ...          ...      ...      ...     ...     ...     ...     ...     ...
# 12735  2038.1976  13.3214  47.5611  2.1493   0.086  2.4922  2.5933  1.5312
# 12736    2038.35  13.3292  46.9579  2.1972  0.0865  2.1937  2.2315   1.522
# 12737  2038.5024  13.3443  45.3758  2.2765  0.0869   1.879  1.9364  1.5135
# 12738  2038.6548  13.3437  43.3764  2.3927  0.0872  1.9995  1.9078  1.5052
# 12739  2038.8072  13.3215    41.27  2.5185  0.0866  2.1289  1.9915  1.5005
#
#          NPHI    RHOB     SFL        SP
# ...

# %%
l5.replace(-999.25,np.nan, inplace=True)
l5.dropna(inplace=True)

# %%
l5
# Out:
#            DEPTH      CALI    CILD     DRHO        DT       GR     ILD  \
# 8428     1283.97  343.7717  1.3128   -929.5  128.6453  38.8928  0.7616
# 8429   1284.1224  345.2498   1.334     -944    129.25    38.75   0.749
# 8430   1284.2748    345.25   1.334     -921    129.25    38.75   0.749
# 8431   1284.4272  345.2498   1.334     -890    129.25    38.75   0.749
# 8432   1284.5796  345.2498   1.334   -895.5    129.25    38.75   0.749
# ...          ...       ...     ...      ...       ...      ...     ...
# 13801  2102.8152  318.4998   0.378 -38.1875      74.5  73.0625  2.6438
# 13802  2102.9676     318.5   0.378   -42.25      74.5  73.0625   2.643
# 13803    2103.12  317.0232   0.378 -41.0938      74.5  73.0625  2.6426
# 13804  2103.2724  314.0232   0.378 -45.2812      74.5  73.0625  2.6426
# 13805  2103.4248  311.0232   0.378 -51.1875      74.5  73.0625  2.6426
#
#          NPHI  RHOB    SFLA    SFLU       SP     CNLF    CNLN
# ...

# %%
from scipy.stats import pearsonr
r,p=pearsonr(l1['DEPTH'],l1['CALI'])
r1,p1=pearsonr(l1['DEPTH'],l1['GR'])
r2,p2=pearsonr(l1['DEPTH'],l1['ILD'])
r3,p4=pearsonr(l1['DEPTH'],l1['ITT'])
r4,p4=pearsonr(l1['DEPTH'],l1['LLD'])
r5,p5=pearsonr(l1['DEPTH'],l1['LLS'])
r6,p6=pearsonr(l1['DEPTH'],l1['MSFL'])
r7,p7=pearsonr(l1['DEPTH'],l1['NPHI'])
r8,p8=pearsonr(l1['DEPTH'],l1['RHOB'])
r9,p9=pearsonr(l1['DEPTH'],l1['SFL'])
r10,p10=pearsonr(l1['DEPTH'],l1['SP'])
r,r1,r2,r3,r4,r5,r6,r7,r8,r9,r10
# Out:
# (-0.37519499129746525,
#  0.8360237545474826,
#  -0.0029446517355824625,
#  -0.5900472712511559,
#  -0.0641217269592876,
#  -0.016893608196786786,
#  -0.021856274353679532,
#  -0.5374572051366078,
#  0.6064562867502652,
#  -0.008964003322315053,
#  0.1086186921120121)

# %%
r11,p11=pearsonr(l1['GR'],l1['CALI'])
r12,p11=pearsonr(l1['GR'],l1['ILD'])
r13,p13=pearsonr(l1['GR'],l1['ITT'])
r14,p14=pearsonr(l1['GR'],l1['LLD'])
r15,p15=pearsonr(l1['GR'],l1['LLS'])
r16,p16=pearsonr(l1['GR'],l1['MSFL'])
r17,p17=pearsonr(l1['GR'],l1['NPHI'])
r18,p18=pearsonr(l1['GR'],l1['RHOB'])
r19,p19=pearsonr(l1['GR'],l1['SFL'])
r20,p20=pearsonr(l1['GR'],l1['SP'])
r11,r12,r13,r14,r15,r16,r17,r18,r19,r20
# Out:
# (-0.20509910810846801,
#  -0.2033104997147383,
#  -0.40949156308690904,
#  -0.2165577905864121,
#  -0.17559049077725697,
#  -0.19333340968968254,
#  -0.28909892432856754,
#  0.5421501447615471,
#  -0.056497016287075465,
#  0.1567649690368843)

# %%
t=[]
for i in range(len(l1.columns)):
    r,p=pearsonr(l1.iloc[:,3],l1.iloc[:,i])
    t.append(r)
t
# Out:
# [-0.0029446517355824625,
#  -0.385299775734661,
#  -0.2033104997147383,
#  0.9999999999999998,
#  -0.5236279731785211,
#  0.8906386095002601,
#  0.888996783845539,
#  0.6506813044221222,
#  -0.5947047599406811,
#  0.2744550752739587,
#  0.12817705659673068,
#  -0.1857034262239896]

# %%
t=[]
for i in range(len(l1.columns)):
    r,p=pearsonr(l1.iloc[:,4],l1.iloc[:,i])
    t.append(r)
t
# Out:
# [-0.5900472712511559,
#  0.6776297926580566,
#  -0.40949156308690904,
#  -0.5236279731785211,
#  1.0,
#  -0.4254628595210671,
#  -0.48849676484073845,
#  -0.42181725046360313,
#  0.874456137152089,
#  -0.7121276552986036,
#  -0.07180650028729146,
#  0.058616081155614196]

# %%
t=[]
for i in range(len(l1.columns)):
    r,p=pearsonr(l1.iloc[:,4],l1.iloc[:,i])
    t.append(r)
t
# Out:
# [-0.5900472712511559,
#  0.6776297926580566,
#  -0.40949156308690904,
#  -0.5236279731785211,
#  1.0,
#  -0.4254628595210671,
#  -0.48849676484073845,
#  -0.42181725046360313,
#  0.874456137152089,
#  -0.7121276552986036,
#  -0.07180650028729146,
#  0.058616081155614196]

# %%
t=[]
for i in range(len(l1.columns)):
    r,p=pearsonr(l1.iloc[:,5],l1.iloc[:,i])
    t.append(r)
t
# Out:
# [-0.0641217269592876,
#  -0.29701394173536394,
#  -0.2165577905864121,
#  0.8906386095002601,
#  -0.4254628595210671,
#  0.9999999999999999,
#  0.9646341016918899,
#  0.6836545526868135,
#  -0.5042609015026723,
#  0.21203697714042363,
#  0.10866277746760267,
#  -0.19423006585384006]

# %%
t=[]
for i in range(len(l1.columns)):
    r,p=pearsonr(l1.iloc[:,6],l1.iloc[:,i])
    t.append(r)
t
# Out:
# [-0.016893608196786786,
#  -0.36047319594123883,
#  -0.17559049077725697,
#  0.888996783845539,
#  -0.48849676484073845,
#  0.9646341016918899,
#  0.9999999999999998,
#  0.7435169777761537,
#  -0.5623533563196146,
#  0.2819587751169022,
#  0.1092767083289948,
#  -0.20291887177233292]

# %%
t=[]
for i in range(len(l1.columns)):
    r,p=pearsonr(l1.iloc[:,7],l1.iloc[:,i])
    t.append(r)
t
# Out:
# [-0.021856274353679532,
#  -0.3823466927268869,
#  -0.19333340968968254,
#  0.6506813044221222,
#  -0.42181725046360313,
#  0.6836545526868135,
#  0.7435169777761537,
#  0.9999999999999999,
#  -0.49325356807788945,
#  0.29808717122525596,
#  0.11711706179189346,
#  -0.14945369389180257]

# %%
t=[]
for i in range(len(l1.columns)):
    r,p=pearsonr(l1.iloc[:,8],l1.iloc[:,i])
    t.append(r)
t
# Out:
# [-0.5374572051366078,
#  0.6332595902690168,
#  -0.28909892432856754,
#  -0.5947047599406811,
#  0.874456137152089,
#  -0.5042609015026723,
#  -0.5623533563196146,
#  -0.49325356807788945,
#  0.9999999999999998,
#  -0.7386399994931347,
#  -0.07990299846904611,
#  0.08597545500906176]

# %%
t=[]
for i in range(len(l1.columns)):
    r,p=pearsonr(l1.iloc[:,9],l1.iloc[:,i])
    t.append(r)
t
# Out:
# [0.6064562867502652,
#  -0.5581511724683685,
#  0.5421501447615471,
#  0.2744550752739587,
#  -0.7121276552986036,
#  0.21203697714042363,
#  0.2819587751169022,
#  0.29808717122525596,
#  -0.7386399994931347,
#  1.0,
#  0.030698326718216856,
#  0.05862463909954498]

# %%
t=[]
for i in range(len(l1.columns)):
    r,p=pearsonr(l1.iloc[:,10],l1.iloc[:,i])
    t.append(r)
t
# Out:
# [-0.008964003322315053,
#  -0.05376288535841469,
#  -0.056497016287075465,
#  0.12817705659673068,
#  -0.07180650028729146,
#  0.10866277746760267,
#  0.1092767083289948,
#  0.11711706179189346,
#  -0.07990299846904611,
#  0.030698326718216856,
#  0.9999999999999998,
#  -0.003342984139073809]

# %%
t=[]
for i in range(len(l1.columns)):
    r,p=pearsonr(l1.iloc[:,11],l1.iloc[:,i])
    t.append(r)
t
# Out:
# [0.1086186921120121,
#  0.1196736555572522,
#  0.1567649690368843,
#  -0.1857034262239896,
#  0.058616081155614196,
#  -0.19423006585384006,
#  -0.20291887177233292,
#  -0.14945369389180257,
#  0.08597545500906176,
#  0.05862463909954498,
#  -0.003342984139073809,
#  1.0]

# %%
l1.drop(['LLD','LLS','MSFL','SFL'],axis=1,inplace=True)

# %%
y=l1['RHOB']
X=l1.drop(['RHOB'],axis=1)

# %%
pd.plotting.scatter_matrix(l1,figsize=(20,10),diagonal='kde')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.6844593082659962

# %%
lr.score(X_test,y_test)
# Out:
# 0.704529009963025

# %%
random_state=[x for x in range(200)]
mse_test=[]
mse_train=[]
train_score=[]
test_score=[]
for i in random_state:
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler()
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=i)
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    from sklearn.linear_model import LinearRegression
    lr=LinearRegression()
    lr.fit(X_train,y_train)
    from sklearn.metrics import mean_squared_error
    train_score.append(lr.score(X_train,y_train))
    test_score.append(lr.score(X_test,y_test))
    mse_train.append(mean_squared_error(y_train,lr.predict(X_train)))
    mse_test.append(mean_squared_error(y_test,lr.predict(X_test)))
    df_mse_train=pd.DataFrame(mse_train,columns=['MSE_train'])
    df_mse=pd.DataFrame(mse_test, columns=["MSE_test"])
    df_train=pd.DataFrame(train_score, columns=['Training_score'])
    df_test=pd.DataFrame(test_score,columns=["Test_score"])
    df=pd.merge(df_train,df_test, how='outer', left_index=True, right_index=True)
    df=pd.merge(df,df_mse,how='outer',left_index=True, right_index=True)
    df=pd.merge(df,df_mse_train,how='outer',left_index=True, right_index=True)

# %%
mse_train
# Out:
# [0.004575677727015071,
#  0.004556281761030248,
#  0.004533146326928951,
#  0.004516465183993078,
#  0.004517676070028484,
#  0.004559564692265594,
#  0.004428150564097439,
#  0.004523699962866328,
#  0.004436633510720373,
#  0.004482851640719152,
#  0.0045527127860370276,
#  0.004597137556320189,
#  0.004588018520648867,
#  0.0045615093883334444,
#  0.004453956577994581,
#  0.004369807736487612,
#  0.004437743128492871,
#  0.004581047007976404,
#  0.0044284760077446745,
#  0.004509083196654664,
#  0.004409990138320824,
#  0.004417120306465916,
#  0.004579997967428102,
#  0.0045271622325199126,
#  0.004486731438771064,
#  0.004536797582423205,
#  0.004447317861280179,
#  0.004494112117846841,
#  0.004535192492950442,
#  0.004494430374944092,
#  0.004474595937557197,
#  0.004563190528999116,
#  0.004463625724497554,
#  0.004496163635337965,
#  0.004573428814443375,
#  0.0045057356808772524,
#  0.004499257944255499,
#  0.004526762480490259,
#  0.004566277236313291,
# ...

# %%
mse_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 mse_
#
# NameError: name 'mse_' is not defined

# %%
train_score=np.array(train_score)
train_score

# %%
test_score=np.array(test_score)

# %% [markdown]
# # Finding out the largest test score

# %%
df[df['Test_score']==max(test_score)]

# %% [markdown]
# # Finding the lowest mse on the test set

# %%
df[df['MSE_test']==min(mse_test)]

# %% [markdown]
# # Using SVR

# %% [markdown]
# # Selecting the best random states and regularizing

# %% [markdown]
# #### Random state = 39

# %%
mse_test=[]
mse_train=[]
train_score=[]
test_score=[]
for i in random_state:
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler()
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=i)
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    from sklearn.svm import SVR
    svr=SVR()
    svr.fit(X_train,y_train)
    from sklearn.metrics import mean_squared_error
    train_score.append(svr.score(X_train,y_train))
    test_score.append(svr.score(X_test,y_test))
    mse_train.append(mean_squared_error(y_train,svr.predict(X_train)))
    mse_test.append(mean_squared_error(y_test,svr.predict(X_test)))
    df_mse_train=pd.DataFrame(mse_train,columns=['MSE_train'])
    df_mse=pd.DataFrame(mse_test, columns=["MSE_test"])
    df_train=pd.DataFrame(train_score, columns=['Training_score'])
    df_test=pd.DataFrame(test_score,columns=["Test_score"])
    df=pd.merge(df_train,df_test, how='outer', left_index=True, right_index=True)
    df=pd.merge(df,df_mse,how='outer',left_index=True, right_index=True)
    df=pd.merge(df,df_mse_train,how='outer',left_index=True, right_index=True)

# %%
df[df['Test_score']==max(test_score)]

# %%
df[df['MSE_test']==min(mse_test)]

# %% [markdown]
# # Choosing random states 33 and 55

# %% [markdown]
# #### Regularizing

# %%
c

# %%
mse_test=[]
mse_train=[]
train_score=[]
test_score=[]
c= np.linspace(2,2.9,50)
for i in c:
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler()
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=33)
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    from sklearn.svm import SVR
    svr=SVR(C=i)
    svr.fit(X_train,y_train)
    from sklearn.metrics import mean_squared_error
    train_score.append(svr.score(X_train,y_train))
    test_score.append(svr.score(X_test,y_test))
    mse_train.append(mean_squared_error(y_train,svr.predict(X_train)))
    mse_test.append(mean_squared_error(y_test,svr.predict(X_test)))
    df_mse_train=pd.DataFrame(mse_train,columns=['MSE_train'])
    df_mse=pd.DataFrame(mse_test, columns=["MSE_test"])
    df_train=pd.DataFrame(train_score, columns=['Training_score'])
    df_test=pd.DataFrame(test_score,columns=["Test_score"])
    df=pd.merge(df_train,df_test, how='outer', left_index=True, right_index=True)
    df=pd.merge(df,df_mse,how='outer',left_index=True, right_index=True)
    df=pd.merge(df,df_mse_train,how='outer',left_index=True, right_index=True)

# %%
df[df['Test_score']==max(test_score)]

# %%
df

# %%
mse_test=[]
mse_train=[]
train_score=[]
test_score=[]
c= np.linspace(1000,1200,5)
for i in c:
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler()
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=55)
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    from sklearn.svm import SVR
    svr=SVR(C=i)
    svr.fit(X_train,y_train)
    from sklearn.metrics import mean_squared_error
    train_score.append(svr.score(X_train,y_train))
    test_score.append(svr.score(X_test,y_test))
    mse_train.append(mean_squared_error(y_train,svr.predict(X_train)))
    mse_test.append(mean_squared_error(y_test,svr.predict(X_test)))
    df_mse_train=pd.DataFrame(mse_train,columns=['MSE_train'])
    df_mse=pd.DataFrame(mse_test, columns=["MSE_test"])
    df_train=pd.DataFrame(train_score, columns=['Training_score'])
    df_test=pd.DataFrame(test_score,columns=["Test_score"])
    df=pd.merge(df_train,df_test, how='outer', left_index=True, right_index=True)
    df=pd.merge(df,df_mse,how='outer',left_index=True, right_index=True)
    df=pd.merge(df,df_mse_train,how='outer',left_index=True, right_index=True)

# %%
df

# %%
svr
svr.fit(X_train,y_train)

# %%
svr.score(X_test,y_test)

# %%
df=pd.DataFrame(X_test[:,0],columns=['Depth'])
yt=pd.DataFrame(y_test)
yt.index=df.index
df=pd.merge(df,yt,'outer', left_index=True,right_index=True)
yp=pd.DataFrame(svr.predict(X_test),columns=['RHOB_Predict'])
df=df.merge(yp,'outer',left_index=True,right_index=True)
df=df.sort_values(by='Depth',ascending=True)
df

# %%
X_test,y_test

# %%
plt.plot(y_y,X_x[:,0])
plt.plot(np.sort(svr.predict(X_test)),X_x[:,0])

# %%
plt.plot(df['RHOB'],df['Depth'])
plt.plot(df['RHOB_Predict'],df['Depth'])
