# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
l1=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name='1S 1X',header=[3])

# %%
l2=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name=' 1S 2X',header=[3])

# %%
l3=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name='1S 3AX',header=[3])

# %%
l4=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name=' 1S 4X',header=[3])

# %%
l5=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name='1S 5X',header=[3])

# %%
l1.drop([0], inplace=True)

# %%
l1.replace(-999.25,np.nan,inplace=True)

# %%
l1=l1.dropna()

# %%
l1
# Out:
#            DEPTH     CALI        GR     ILD     ITT     LLD     LLS    MSFL  \
# 9401   1524.0000  14.4538   54.8415  0.9607  0.1233  0.9879  1.0776  1.4853
# 9402   1524.1524  14.0887   55.8918  0.9660  0.1231  0.9906  1.0821  1.5206
# 9403   1524.3048  13.8190   57.2492  0.9624  0.1238  0.9823  1.0876  1.4323
# 9404   1524.4572  13.7363   58.0199  0.9399  0.1252  0.9660  1.0079  1.3148
# 9405   1524.6096  13.8716   58.2939  0.9146  0.1256  0.9360  1.0188  1.2740
# ...          ...      ...       ...     ...     ...     ...     ...     ...
# 23253  3635.0448   9.3138  115.5579  2.1824  0.0854  2.1704  2.5690  3.1694
# 23254  3635.1972   9.1831  115.3115  2.2141  0.0859  2.1827  2.5769  2.8899
# 23255  3635.3496   8.9994  114.8351  2.2159  0.0865  2.1733  2.5695  1.2580
# 23256  3635.5020   8.9888  115.0071  2.1779  0.0863  2.1579  2.5616  0.7530
# 23257  3635.6544   8.9945  116.4589  2.1265  0.0856  2.1191  2.5447  0.8664
#
#          NPHI    RHOB     SFL       SP
# ...

# %%
l2.dropna()
# Out:
#            DEPTH     CALI        GR     ILD     ITT     LLD     LLS    MSFL  \
# 3         121.92  -999.25    13.151 -999.25 -999.25 -999.25 -999.25 -999.25
# 4       122.0724  -999.25   13.3995 -999.25 -999.25 -999.25 -999.25 -999.25
# 5       122.2248  -999.25   13.5588 -999.25 -999.25 -999.25 -999.25 -999.25
# 6       122.3772  -999.25   13.6787 -999.25 -999.25 -999.25 -999.25 -999.25
# 7       122.5296  -999.25   13.7763 -999.25 -999.25 -999.25 -999.25 -999.25
# ...          ...      ...       ...     ...     ...     ...     ...     ...
# 20899  3306.4704  12.6247  106.5361  2.5241   0.087  1.9885  2.3306  2.9424
# 20900  3306.6228  12.6271  104.1838   2.446   0.087  2.0045  2.3176  2.9974
# 20901  3306.7752  12.6282  110.7324  2.3721   0.087  2.0225  2.3032  3.0224
# 20902  3306.9276  12.6273  115.5901  2.3395  0.0871  2.0349  2.2898  3.0355
# 20903    3307.08  12.6269   118.256  2.2852  0.0871  2.0428  2.2882  3.0393
#
#          NPHI    RHOB     SFL        SP
# ...

# %%
l2.replace(-999.25,np.nan, inplace=True)

# %%
l2=l2.dropna()

# %%
l2=l2.reset_index()

# %%
from scipy.stats import pearsonr

c,p=pearsonr(l2.RHOB,l2.NPHI)
c1,p1=pearsonr(l2.RHOB,l2.SP)
c1
# Out:
# -0.46167312244741987

# %%
l3.replace(-999.25,np.nan,inplace=True)

# %%
l3.dropna(inplace=True)

# %%
l3
# Out:
#            DEPTH     CALI       GR     ILD     ITT     LLD     LLS    MSFL  \
# 9763     1615.44  15.2401  59.0503  0.9317  0.1323  0.9221  1.0336   1.183
# 9764   1615.5924   15.231  57.2185  0.9513  0.1321  0.9044  1.0357  1.1894
# 9765   1615.7448  15.1242  55.8582   0.971  0.1319   0.893  1.0343   1.198
# 9766   1615.8972  14.9753  55.9452  0.9793   0.132  0.8849  1.0286   1.204
# 9767   1616.0496  14.8822  56.3107  0.9858  0.1325  0.8824  1.0108  1.2096
# ...          ...      ...      ...     ...     ...     ...     ...     ...
# 17075  2729.7888  12.2535  85.9298  1.8382  0.0931  2.2281  2.6699  0.5899
# 17076  2729.9412  12.2412  85.4963  1.8557  0.0938  2.2328  2.6854  0.5421
# 17077  2730.0936  12.2509  86.1886  1.8716  0.0944  2.2375  2.6957  0.4983
# 17078   2730.246  12.2523  86.9371  1.8809  0.0947  2.2525   2.706  0.4652
# 17079  2730.3984  12.2481   85.392  1.8809  0.0948  2.2681  2.7164  0.4751
#
#          NPHI    RHOB     SFL       SP
# ...

# %%
l4.replace(-999.25,np.nan,inplace=True)
l4.dropna(inplace=True)

# %%
l4
# Out:
#      SP
# SP  1.0

# %%
l5.replace(-999.25,np.nan, inplace=True)
l5.dropna(inplace=True)

# %%
l5
# Out:
#            DEPTH      CALI    CILD     DRHO        DT       GR     ILD  \
# 8428     1283.97  343.7717  1.3128   -929.5  128.6453  38.8928  0.7616
# 8429   1284.1224  345.2498   1.334     -944    129.25    38.75   0.749
# 8430   1284.2748    345.25   1.334     -921    129.25    38.75   0.749
# 8431   1284.4272  345.2498   1.334     -890    129.25    38.75   0.749
# 8432   1284.5796  345.2498   1.334   -895.5    129.25    38.75   0.749
# ...          ...       ...     ...      ...       ...      ...     ...
# 13801  2102.8152  318.4998   0.378 -38.1875      74.5  73.0625  2.6438
# 13802  2102.9676     318.5   0.378   -42.25      74.5  73.0625   2.643
# 13803    2103.12  317.0232   0.378 -41.0938      74.5  73.0625  2.6426
# 13804  2103.2724  314.0232   0.378 -45.2812      74.5  73.0625  2.6426
# 13805  2103.4248  311.0232   0.378 -51.1875      74.5  73.0625  2.6426
#
#          NPHI  RHOB    SFLA    SFLU       SP     CNLF    CNLN
# ...

# %%
l1.corr(method='pearson')
# Out:
#           DEPTH      CALI        GR       ILD       ITT       LLD       LLS  \
# DEPTH  1.000000 -0.375195  0.836024 -0.002945 -0.590047 -0.064122 -0.016894
# CALI  -0.375195  1.000000 -0.205099 -0.385300  0.677630 -0.297014 -0.360473
# GR     0.836024 -0.205099  1.000000 -0.203310 -0.409492 -0.216558 -0.175590
# ILD   -0.002945 -0.385300 -0.203310  1.000000 -0.523628  0.890639  0.888997
# ITT   -0.590047  0.677630 -0.409492 -0.523628  1.000000 -0.425463 -0.488497
# LLD   -0.064122 -0.297014 -0.216558  0.890639 -0.425463  1.000000  0.964634
# LLS   -0.016894 -0.360473 -0.175590  0.888997 -0.488497  0.964634  1.000000
# MSFL  -0.021856 -0.382347 -0.193333  0.650681 -0.421817  0.683655  0.743517
# NPHI  -0.537457  0.633260 -0.289099 -0.594705  0.874456 -0.504261 -0.562353
# RHOB   0.606456 -0.558151  0.542150  0.274455 -0.712128  0.212037  0.281959
# SFL   -0.008964 -0.053763 -0.056497  0.128177 -0.071807  0.108663  0.109277
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(l1.corr(),annot=True)
plt.show()

# %%
l1.columns
# Out:
# Index(['DEPTH', 'CALI', 'GR', 'ILD', 'ITT', 'LLD', 'LLS', 'MSFL', 'NPHI',
#        'RHOB', 'SFL', 'SP'],
#       dtype='object')

# %%
l1[['DEPTH', 'CALI', 'GR', 'ITT', 'LLS', 'NPHI']].corr()
# Out:
#           DEPTH      CALI        GR       ITT       LLS      NPHI
# DEPTH  1.000000 -0.375195  0.836024 -0.590047 -0.016894 -0.537457
# CALI  -0.375195  1.000000 -0.205099  0.677630 -0.360473  0.633260
# GR     0.836024 -0.205099  1.000000 -0.409492 -0.175590 -0.289099
# ITT   -0.590047  0.677630 -0.409492  1.000000 -0.488497  0.874456
# LLS   -0.016894 -0.360473 -0.175590 -0.488497  1.000000 -0.562353
# NPHI  -0.537457  0.633260 -0.289099  0.874456 -0.562353  1.000000

# %%
l1[['DEPTH', 'CALI', 'GR', 'ITT', 'LLS', 'NPHI']]
# Out:
#            DEPTH     CALI        GR     ITT     LLS    NPHI
# 9401   1524.0000  14.4538   54.8415  0.1233  1.0776  0.4397
# 9402   1524.1524  14.0887   55.8918  0.1231  1.0821  0.4255
# 9403   1524.3048  13.8190   57.2492  0.1238  1.0876  0.4351
# 9404   1524.4572  13.7363   58.0199  0.1252  1.0079  0.4469
# 9405   1524.6096  13.8716   58.2939  0.1256  1.0188  0.4353
# ...          ...      ...       ...     ...     ...     ...
# 23253  3635.0448   9.3138  115.5579  0.0854  2.5690  0.2417
# 23254  3635.1972   9.1831  115.3115  0.0859  2.5769  0.2614
# 23255  3635.3496   8.9994  114.8351  0.0865  2.5695  0.2754
# 23256  3635.5020   8.9888  115.0071  0.0863  2.5616  0.2617
# 23257  3635.6544   8.9945  116.4589  0.0856  2.5447  0.2451
#
# [13857 rows x 6 columns]

# %%
sns.pairplot(data=l1[['DEPTH', 'CALI', 'GR', 'ITT', 'LLS', 'NPHI']])

# %%
y=l1['RHOB']
X=l1[['DEPTH', 'CALI', 'GR', 'ITT', 'LLS', 'NPHI']]

# %%
pd.plotting.scatter_matrix(l1,figsize=(20,10),diagonal='kde')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.6782384016514945

# %%
lr.score(X_test,y_test)
# Out:
# 0.6963305276959654

# %%
random_state=[x for x in range(201)]
mse_test=[]
mse_train=[]
train_score=[]
test_score=[]
for i in random_state:
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler()
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=i)
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    from sklearn.linear_model import LinearRegression
    lr=LinearRegression()
    lr.fit(X_train,y_train)
    from sklearn.metrics import mean_squared_error
    train_score.append(lr.score(X_train,y_train))
    test_score.append(lr.score(X_test,y_test))
    mse_train.append(mean_squared_error(y_train,lr.predict(X_train)))
    mse_test.append(mean_squared_error(y_test,lr.predict(X_test)))

# %%
mse_train
# Out:
# [0.004665887530642591,
#  0.004651761007754359,
#  0.0046141159096682455,
#  0.004616694554438191,
#  0.004601049505914365,
#  0.004666377806183421,
#  0.004535835427565266,
#  0.004626853013399842,
#  0.0045302596259174256,
#  0.004574684252673855,
#  0.004645257699975033,
#  0.004706186848308421,
#  0.004722279937907724,
#  0.004653367345653519,
#  0.004560647524424299,
#  0.0044615111480583395,
#  0.004537134845753717,
#  0.004675069571363701,
#  0.00452504586357406,
#  0.00460705476159687,
#  0.00449548548511128,
#  0.004516754356244939,
#  0.004680939248948968,
#  0.004630520562203361,
#  0.004577195091964165,
#  0.004631942145703829,
#  0.004550216122877961,
#  0.004594356851295229,
#  0.004632166087471823,
#  0.004588525587742884,
#  0.004568893492289443,
#  0.0046550701548934165,
#  0.004557484906264931,
#  0.004604005159649321,
#  0.004666798624282601,
#  0.004601276298739267,
#  0.004599496121758612,
#  0.004622881242952941,
#  0.004666442936507514,
# ...

# %%
mse_test
# Out:
# [0.0044549057758933135,
#  0.004500202547029585,
#  0.004608278512263398,
#  0.00460001359794814,
#  0.004647672254972071,
#  0.0044524403402890905,
#  0.004845706872040623,
#  0.0045703151552178465,
#  0.004863196148053214,
#  0.004726065795376628,
#  0.004517402743384994,
#  0.004343639320634045,
#  0.004285151955836503,
#  0.004490239551543326,
#  0.004768665964413778,
#  0.005067162593313304,
#  0.0048407941094364675,
#  0.004426195195453304,
#  0.004876144517016839,
#  0.00463719724962557,
#  0.004963937765025337,
#  0.004901100039248134,
#  0.004409850670729704,
#  0.004558814393212346,
#  0.004722188548016049,
#  0.0045554195724775036,
#  0.004802018916561149,
#  0.004669420661191735,
#  0.004555522735216405,
#  0.004684735473254629,
#  0.004744406752637332,
#  0.004485807107704274,
#  0.00478047209138614,
#  0.004641067482705171,
#  0.004451884521971118,
#  0.00464795498391516,
#  0.004651661354417168,
#  0.004584925996181884,
#  0.004451276729634618,
# ...

# %%
train_score=np.array(train_score)
train_score
# Out:
# array([0.6782384 , 0.67614886, 0.68162887, 0.68387781, 0.68468048,
#        0.67405547, 0.68485354, 0.68398508, 0.6901858 , 0.68639921,
#        0.67575934, 0.68440168, 0.67845592, 0.68044469, 0.68298939,
#        0.6904058 , 0.68718076, 0.68322748, 0.68997753, 0.68114529,
#        0.68891958, 0.6832787 , 0.67832525, 0.67759907, 0.68618041,
#        0.683306  , 0.68612269, 0.68094801, 0.68274338, 0.6836506 ,
#        0.68498759, 0.67857762, 0.68674782, 0.67650738, 0.67966311,
#        0.6866916 , 0.68131918, 0.6829454 , 0.67936787, 0.67218296,
#        0.68841312, 0.68484487, 0.68361407, 0.68067329, 0.68573726,
#        0.68478525, 0.68097674, 0.68511038, 0.6847005 , 0.68792229,
#        0.68507671, 0.68367136, 0.68758093, 0.68466571, 0.67861647,
#        0.67820047, 0.68279875, 0.68475114, 0.68334065, 0.68204221,
#        0.67791632, 0.68349522, 0.68965433, 0.68567337, 0.68484165,
#        0.68323846, 0.68277427, 0.68396937, 0.67982978, 0.68039412,
# ...

# %%
test_score=np.array(test_score)

# %%
test_score
# Out:
# array([0.69633053, 0.70169855, 0.68651311, 0.67982124, 0.67710403,
#        0.70756434, 0.67687567, 0.67939769, 0.66008433, 0.67211094,
#        0.70278578, 0.67671739, 0.69646955, 0.69011076, 0.68244906,
#        0.66098859, 0.66993252, 0.68159777, 0.66116948, 0.6873499 ,
#        0.66515813, 0.68144131, 0.6963531 , 0.69755099, 0.67259822,
#        0.68147552, 0.67306188, 0.6880397 , 0.68314912, 0.68054495,
#        0.67648318, 0.69548521, 0.67103549, 0.70006935, 0.69215978,
#        0.67076837, 0.68740133, 0.68241308, 0.69330366, 0.71316576,
#        0.66579282, 0.67647384, 0.68057721, 0.68926507, 0.67434553,
#        0.67699498, 0.6882251 , 0.67634093, 0.67648388, 0.66702643,
#        0.67615725, 0.68057856, 0.66808239, 0.6770408 , 0.69540615,
#        0.69747001, 0.68251736, 0.67685409, 0.68138482, 0.68466635,
#        0.69706213, 0.68102032, 0.66081039, 0.67459671, 0.67692125,
#        0.68166849, 0.68304647, 0.67901823, 0.69143443, 0.69038856,
# ...

# %%
np.mean(test_score)
# Out:
# 0.6831191441363009

# %%
np.mean(train_score)
# Out:
# 0.6826845264872945

# %% [markdown]
# # SVR

# %%
random_state=[x for x in range(201)]
mse_test=[]
mse_train=[]
train_score=[]
test_score=[]
for i in random_state:
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler()
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=i,train_size=.9)
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    from sklearn.svm import SVR
    lr=SVR()
    lr.fit(X_train,y_train)
    from sklearn.metrics import mean_squared_error
    train_score.append(lr.score(X_train,y_train))
    test_score.append(lr.score(X_test,y_test))
    mse_train.append(mean_squared_error(y_train,lr.predict(X_train)))
    mse_test.append(mean_squared_error(y_test,lr.predict(X_test)))

# %%
train_score
# Out:
# [0.740656354774861,
#  0.7403610788140291,
#  0.7441774067969505,
#  0.743774452019385,
#  0.7435203749350563,
#  0.7396621703082447,
#  0.7429513520984614,
#  0.7443190867015772,
#  0.7445410206419318,
#  0.7416410656437395,
#  0.742591990386649,
#  0.7432831713904529,
#  0.7421891453898701,
#  0.7402595065502284,
#  0.742289968692279,
#  0.741847127305646,
#  0.7447191807645136,
#  0.7438635886044017,
#  0.7438494348289169,
#  0.7443601795274533,
#  0.7440084107057472,
#  0.7414141708055575,
#  0.744585204354888,
#  0.7444224821369113,
#  0.7444905392246179,
#  0.7431828151743065,
#  0.7459835821588993,
#  0.7429288918736052,
#  0.7415050139231745,
#  0.7467295576127706,
#  0.742615580506454,
#  0.7408872707869527,
#  0.7416589004347205,
#  0.7372074829388433,
#  0.7405365700688764,
#  0.7440382011578017,
#  0.7415906253971198,
#  0.7447731357620119,
#  0.7445220296562698,
#  0.7402659446957784,
#  0.7415346768282817,
#  0.7453278657312968,
#  0.7420682129958067,
# ...

# %%
np.mean(test_score)
# Out:
# 0.7377600764627789

# %%
l2.replace(-999.25,np.nan, inplace=True)
# Out:
# C:\Users\Paa Kwasi\AppData\Local\Temp\ipykernel_25856\3095484476.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l2.replace(-999.25,np.nan, inplace=True)

# %%
l2=l2.dropna()

# %%
X_tested=l2[['DEPTH', 'CALI', 'GR', 'ITT', 'LLS', 'NPHI']]
y_tested=l2['RHOB']

# %%
XT=scaler.fit_transform(X_tested)

# %%
lr.score(XT,y_tested)
# Out:
# -0.6085172976221596

# %%
X=l2[['DEPTH', 'CALI', 'GR', 'ITT', 'LLS', 'NPHI']]
y=l2['RHOB']
random_state=[x for x in range(201)]
mse_test=[]
mse_train=[]
train_score=[]
test_score=[]
for i in random_state:
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler()
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=i,train_size=.9)
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    from sklearn.svm import SVR
    lr=SVR()
    lr.fit(X_train,y_train)
    from sklearn.metrics import mean_squared_error
    train_score.append(lr.score(X_train,y_train))
    test_score.append(lr.score(X_test,y_test))
    mse_train.append(mean_squared_error(y_train,lr.predict(X_train)))
    mse_test.append(mean_squared_error(y_test,lr.predict(X_test)))

# %%
train_score
# Out:
# [0.8139923505325534,
#  0.8113264677582058,
#  0.8095567710612244,
#  0.8120566283178156,
#  0.8095833712553966,
#  0.8067676260336012,
#  0.8082424821574283,
#  0.8119033536507767,
#  0.8108749757666289,
#  0.8095594294486573,
#  0.811159960146703,
#  0.8116877116807526,
#  0.8085435740328014,
#  0.813295775302763,
#  0.8087661636375785,
#  0.8113806599388991,
#  0.8124822442059185,
#  0.8092810589042007,
#  0.8092980023944899,
#  0.8089919148632982,
#  0.8097999192437333,
#  0.8097888132584509,
#  0.8096044647021596,
#  0.8114680140657006,
#  0.8123019278450498,
#  0.8082401295226378,
#  0.8051794552027737,
#  0.8099007267077425,
#  0.8077212914045568,
#  0.8122171139530556,
#  0.8088635082438868,
#  0.8091526387935215,
#  0.8069035169333785,
#  0.8090040239828983,
#  0.8079089904188372,
#  0.8092734107795986,
#  0.8109858386396785,
#  0.8103564086029093,
#  0.81389409833818,
#  0.8093715937723791,
#  0.8080667583848798,
#  0.8120813912613025,
#  0.8107983375515089,
# ...

# %%
test_score
# Out:
# [0.7824450326003418,
#  0.8011100944293869,
#  0.8024307851309922,
#  0.7910353024157138,
#  0.7918288065886099,
#  0.8173041008657738,
#  0.8130825041947526,
#  0.7869172220181834,
#  0.8003928352736771,
#  0.8072704811448416,
#  0.8010669119057918,
#  0.789010241843067,
#  0.8185236990330107,
#  0.7950660782562008,
#  0.8167179141218701,
#  0.7913391241017477,
#  0.7862255315437611,
#  0.8074640803656545,
#  0.8032266315965493,
#  0.8109281197224146,
#  0.8104795229493429,
#  0.8093021185810411,
#  0.8092935740040612,
#  0.7840295195551297,
#  0.8023562070175881,
#  0.8190603174798208,
#  0.8351965489240983,
#  0.8064616825585319,
#  0.8077391169907143,
#  0.7985831389608429,
#  0.8158307023086331,
#  0.8093399600618534,
#  0.8167463191883078,
#  0.8133616740094669,
#  0.8201971850966641,
#  0.8116096316313824,
#  0.7961368022337758,
#  0.7997825056328752,
#  0.7861604945143565,
#  0.8156804091953449,
#  0.8234902036313935,
#  0.8036865288980768,
#  0.8079652076130348,
# ...

# %%
np.mean(test_score)
# Out:
# 0.8069079830566818

# %%
np.mean(train_score)
# Out:
# 0.8095961107795476
