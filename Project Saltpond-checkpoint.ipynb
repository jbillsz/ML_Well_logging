# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
l1=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name='1S 1X',header=[3])

# %%
l2=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name=' 1S 2X',header=[3])

# %%
l3=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name='1S 3AX',header=[3])

# %%
l4=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name=' 1S 4X',header=[3])

# %%
l5=pd.read_excel('C:/Users/Paa Kwasi/Desktop/well Logs/logs combined.xlsx',sheet_name='1S 5X',header=[3])

# %%
l1.drop([0], inplace=True)

# %%
l1.replace(-999.25,np.nan,inplace=True)

# %%
l1=l1.dropna()

# %%
l1
# Out:
#            DEPTH     CALI        GR     ILD     ITT     LLD     LLS    MSFL  \
# 9401   1524.0000  14.4538   54.8415  0.9607  0.1233  0.9879  1.0776  1.4853
# 9402   1524.1524  14.0887   55.8918  0.9660  0.1231  0.9906  1.0821  1.5206
# 9403   1524.3048  13.8190   57.2492  0.9624  0.1238  0.9823  1.0876  1.4323
# 9404   1524.4572  13.7363   58.0199  0.9399  0.1252  0.9660  1.0079  1.3148
# 9405   1524.6096  13.8716   58.2939  0.9146  0.1256  0.9360  1.0188  1.2740
# ...          ...      ...       ...     ...     ...     ...     ...     ...
# 23253  3635.0448   9.3138  115.5579  2.1824  0.0854  2.1704  2.5690  3.1694
# 23254  3635.1972   9.1831  115.3115  2.2141  0.0859  2.1827  2.5769  2.8899
# 23255  3635.3496   8.9994  114.8351  2.2159  0.0865  2.1733  2.5695  1.2580
# 23256  3635.5020   8.9888  115.0071  2.1779  0.0863  2.1579  2.5616  0.7530
# 23257  3635.6544   8.9945  116.4589  2.1265  0.0856  2.1191  2.5447  0.8664
#
#          NPHI    RHOB     SFL       SP
# 9401   0.4397  2.2471  1.2134  39.9174
# 9402   0.4255  2.2587  1.1890  39.9393
# 9403   0.4351  2.2589  1.1610  39.3027
# 9404   0.4469  2.2546  1.1243  38.6237
# 9405   0.4353  2.2515  1.0922  38.2129
# ...       ...     ...     ...      ...
# 23253  0.2417  2.5226  2.6407  11.5939
# 23254  0.2614  2.4981  2.6294  10.5358
# 23255  0.2754  2.5023  2.6371  10.2207
# 23256  0.2617  2.5252  2.6507  10.0463
# 23257  0.2451  2.5331  2.6584   9.4207
#
# [13857 rows x 12 columns]

# %%
l2.drop([0,1,2],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 l2.drop([0,1,2],inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: '[0, 1, 2] not found in axis'

# %%
l2.replace(-999.25,np.nan, inplace=True)

# %%
l2=l2.dropna()

# %%
l2
# Out:
#            DEPTH     CALI        GR     ILD     ITT     LLD     LLS    MSFL  \
# 9583   1581.9120  14.6117   72.3413  0.9733  0.1365  0.8844  1.0454  0.8075
# 9584   1582.0644  15.1402   71.4789  0.9894  0.1349  0.9197  1.0387  0.6889
# 9585   1582.2168  15.1520   71.2632  1.0084  0.1336  0.9416  1.0216  0.6483
# 9586   1582.3692  14.8484   69.6416  1.0274  0.1324  0.9429  0.9988  0.6234
# 9587   1582.5216  15.4542   68.1555  1.0387  0.1306  0.9288  0.9763  0.7767
# ...          ...      ...       ...     ...     ...     ...     ...     ...
# 20899  3306.4704  12.6247  106.5361  2.5241  0.0870  1.9885  2.3306  2.9424
# 20900  3306.6228  12.6271  104.1838  2.4460  0.0870  2.0045  2.3176  2.9974
# 20901  3306.7752  12.6282  110.7324  2.3721  0.0870  2.0225  2.3032  3.0224
# 20902  3306.9276  12.6273  115.5901  2.3395  0.0871  2.0349  2.2898  3.0355
# 20903  3307.0800  12.6269  118.2560  2.2852  0.0871  2.0428  2.2882  3.0393
#
#          NPHI    RHOB     SFL       SP
# 9583   0.4041  2.3035  0.9608  63.9524
# 9584   0.4176  2.3111  0.9698  63.8961
# 9585   0.4203  2.3133  0.9879  63.7820
# 9586   0.4107  2.3050  1.0063  63.6584
# 9587   0.4081  2.3296  1.0335  63.5299
# ...       ...     ...     ...      ...
# 20899  0.2441  2.6164  3.3535  74.8055
# 20900  0.2422  2.6269  3.0081  74.3804
# 20901  0.2389  2.6341  2.7091  73.8879
# 20902  0.2327  2.6251  2.4682  73.6399
# 20903  0.2277  2.6125  2.5045  73.7065
#
# [11320 rows x 12 columns]

# %%
l3.replace(-999.25,np.nan,inplace=True)

# %%
l3.dropna(inplace=True)

# %%
l3
# Out:
#            DEPTH     CALI       GR     ILD     ITT     LLD     LLS    MSFL  \
# 9763     1615.44  15.2401  59.0503  0.9317  0.1323  0.9221  1.0336   1.183
# 9764   1615.5924   15.231  57.2185  0.9513  0.1321  0.9044  1.0357  1.1894
# 9765   1615.7448  15.1242  55.8582   0.971  0.1319   0.893  1.0343   1.198
# 9766   1615.8972  14.9753  55.9452  0.9793   0.132  0.8849  1.0286   1.204
# 9767   1616.0496  14.8822  56.3107  0.9858  0.1325  0.8824  1.0108  1.2096
# ...          ...      ...      ...     ...     ...     ...     ...     ...
# 17075  2729.7888  12.2535  85.9298  1.8382  0.0931  2.2281  2.6699  0.5899
# 17076  2729.9412  12.2412  85.4963  1.8557  0.0938  2.2328  2.6854  0.5421
# 17077  2730.0936  12.2509  86.1886  1.8716  0.0944  2.2375  2.6957  0.4983
# 17078   2730.246  12.2523  86.9371  1.8809  0.0947  2.2525   2.706  0.4652
# 17079  2730.3984  12.2481   85.392  1.8809  0.0948  2.2681  2.7164  0.4751
#
#          NPHI    RHOB     SFL       SP
# 9763   0.4417  2.3256  1.0596  36.9682
# 9764   0.4266  2.3301  1.0718  37.0240
# 9765   0.4224  2.3277  1.0885  37.0763
# 9766   0.4336  2.3299  1.1102  37.1287
# 9767   0.4552  2.3425  1.1364  37.1579
# ...       ...     ...     ...      ...
# 17075  0.2765  2.5826  2.4425  82.8130
# 17076   0.263  2.5764  2.4363  82.7427
# 17077  0.2356  2.5799  2.4108  82.6735
# 17078  0.2232  2.5651  2.3184  82.6100
# 17079  0.2223   2.549  2.3475  82.6700
#
# [7317 rows x 12 columns]

# %%
l4.replace(-999.25,np.nan,inplace=True)
l4.dropna(inplace=True)

# %%
l4
# Out:
#            DEPTH     CALI       GR     ILD     ITT     LLD     LLS    MSFL  \
# 13802  0.2695  2382  3.4434  3.4434 -74.8359  971.000  2902.0
# 13803  0.2695  2386  3.4434  3.4434 -74.9867  971.000  2902.0
# 13804  0.2695  2370  3.4434  3.4434 -75.0867  971.000  2902.0
# 13805  0.2695  2360  3.4434  3.4434 -75.1867  971.000  2902.0
#
# [5378 rows x 14 columns]

# %%
l1.corr()
# Out:
#           DEPTH      CALI        GR       ILD       ITT       LLD       LLS  \
# DEPTH  1.000000 -0.375195  0.836024 -0.002945 -0.590047 -0.064122 -0.016894
# CALI  -0.375195  1.000000 -0.205099 -0.385300  0.677630 -0.297014 -0.360473
# GR     0.836024 -0.205099  1.000000 -0.203310 -0.409492 -0.216558 -0.175590
# ILD   -0.002945 -0.385300 -0.203310  1.000000 -0.523628  0.890639  0.888997
# ITT   -0.590047  0.677630 -0.409492 -0.523628  1.000000 -0.425463 -0.488497
# LLD   -0.064122 -0.297014 -0.216558  0.890639 -0.425463  1.000000  0.964634
# LLS   -0.016894 -0.360473 -0.175590  0.888997 -0.488497  0.964634  1.000000
# MSFL  -0.021856 -0.382347 -0.193333  0.650681 -0.421817  0.683655  0.743517
# NPHI  -0.537457  0.633260 -0.289099 -0.594705  0.874456 -0.504261 -0.562353
# RHOB   0.606456 -0.558151  0.542150  0.274455 -0.712128  0.212037  0.281959
# SFL   -0.008964 -0.053763 -0.056497  0.128177 -0.071807  0.108663  0.109277
# SP     0.108619  0.119674  0.156765 -0.185703  0.058616 -0.194230 -0.202919
#
#            MSFL      NPHI      RHOB       SFL        SP
# DEPTH -0.021856 -0.537457  0.606456 -0.008964  0.108619
# CALI  -0.382347  0.633260 -0.558151 -0.053763  0.119674
# GR    -0.193333 -0.289099  0.542150 -0.056497  0.156765
# ILD    0.650681 -0.594705  0.274455  0.128177 -0.185703
# ITT   -0.421817  0.874456 -0.712128 -0.071807  0.058616
# LLD    0.683655 -0.504261  0.212037  0.108663 -0.194230
# LLS    0.743517 -0.562353  0.281959  0.109277 -0.202919
# MSFL   1.000000 -0.493254  0.298087  0.117117 -0.149454
# NPHI  -0.493254  1.000000 -0.738640 -0.079903  0.085975
# RHOB   0.298087 -0.738640  1.000000  0.030698  0.058625
# SFL    0.117117 -0.079903  0.030698  1.000000 -0.003343
# SP    -0.149454  0.085975  0.058625 -0.003343  1.000000

# %%
plt.figure(figsize=(20,20))
sns.heatmap(l1.corr(),annot=True)
plt.show()

# %%
df=l1.corr()
df[df>=np.abs(0.7)]
# Out:
#           DEPTH  CALI        GR       ILD       ITT       LLD       LLS  \
# DEPTH  1.000000   NaN  0.836024       NaN       NaN       NaN       NaN
# CALI        NaN   1.0       NaN       NaN       NaN       NaN       NaN
# GR     0.836024   NaN  1.000000       NaN       NaN       NaN       NaN
# ILD         NaN   NaN       NaN  1.000000       NaN  0.890639  0.888997
# ITT         NaN   NaN       NaN       NaN  1.000000       NaN       NaN
# LLD         NaN   NaN       NaN  0.890639       NaN  1.000000  0.964634
# LLS         NaN   NaN       NaN  0.888997       NaN  0.964634  1.000000
# MSFL        NaN   NaN       NaN       NaN       NaN       NaN  0.743517
# NPHI        NaN   NaN       NaN       NaN  0.874456       NaN       NaN
# RHOB        NaN   NaN       NaN       NaN       NaN       NaN       NaN
# SFL         NaN   NaN       NaN       NaN       NaN       NaN       NaN
# SP          NaN   NaN       NaN       NaN       NaN       NaN       NaN
#
#            MSFL      NPHI  RHOB  SFL   SP
# DEPTH       NaN       NaN   NaN  NaN  NaN
# CALI        NaN       NaN   NaN  NaN  NaN
# GR          NaN       NaN   NaN  NaN  NaN
# ILD         NaN       NaN   NaN  NaN  NaN
# ITT         NaN  0.874456   NaN  NaN  NaN
# LLD         NaN       NaN   NaN  NaN  NaN
# LLS    0.743517       NaN   NaN  NaN  NaN
# MSFL   1.000000       NaN   NaN  NaN  NaN
# NPHI        NaN  1.000000   NaN  NaN  NaN
# RHOB        NaN       NaN   1.0  NaN  NaN
# SFL         NaN       NaN   NaN  1.0  NaN
# SP          NaN       NaN   NaN  NaN  1.0

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# compute the vif for all given features
def compute_vif(considered_features):
    
    X = df[considered_features]
    # the calculation of variance inflation requires a constant
    X['intercept'] = 1
    
    # create dataframe to store vif values
    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Variable']!='intercept']
    return vif

# %%
considered_features = ['DEPTH','GR','LLD','LLS','ILD',"MSFL","ITT",'NPHI']


# compute vif 
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# C:\Users\Paa Kwasi\AppData\Local\Temp\ipykernel_16536\1656449962.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#   Variable          VIF
# 3      LLS  2107.302739
# 2      LLD  1679.672813
# 4      ILD   236.936692
# 6      ITT   192.123820
# 7     NPHI   147.793146
# 0    DEPTH    94.854556
# 1       GR    84.924475
# 5     MSFL    50.966423

# %%
considered_features.remove('LLS')
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# C:\Users\Paa Kwasi\AppData\Local\Temp\ipykernel_16536\1656449962.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#   Variable         VIF
# 3      ILD  236.933577
# 5      ITT  189.906117
# 2      LLD  152.720265
# 6     NPHI  144.664816
# 0    DEPTH   91.697328
# 1       GR   80.031875
# 4     MSFL   23.274136

# %%
considered_features.remove('ILD')
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# C:\Users\Paa Kwasi\AppData\Local\Temp\ipykernel_16536\1656449962.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#   Variable         VIF
# 4      ITT  154.747893
# 5     NPHI  143.525806
# 0    DEPTH   91.097436
# 1       GR   61.239882
# 2      LLD   22.328300
# 3     MSFL   18.584551

# %%
considered_features.remove('ITT')
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# C:\Users\Paa Kwasi\AppData\Local\Temp\ipykernel_16536\1656449962.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#   Variable        VIF
# 0    DEPTH  90.771607
# 4     NPHI  56.838688
# 1       GR  55.922824
# 2      LLD  20.979373
# 3     MSFL  17.713600

# %%
considered_features.remove('MSFL')
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# C:\Users\Paa Kwasi\AppData\Local\Temp\ipykernel_16536\1656449962.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#   Variable        VIF
# 0    DEPTH  90.155967
# 1       GR  54.154324
# 3     NPHI  42.997380
# 2      LLD  20.012860

# %%
considered_features.remove('GR')
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# C:\Users\Paa Kwasi\AppData\Local\Temp\ipykernel_16536\1656449962.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#   Variable        VIF
# 2     NPHI  37.790521
# 1      LLD  19.684478
# 0    DEPTH  16.604729

# %%
considered_features.remove('LLD')
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# C:\Users\Paa Kwasi\AppData\Local\Temp\ipykernel_16536\1656449962.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#   Variable       VIF
# 0    DEPTH  1.930265
# 1     NPHI  1.930265

# %%
l1=l1.drop(['LLS',"MSFL","ITT"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [122], in <cell line: 1>()
# ----> 1 l1=l1.drop(['LLS',"MSFL","ITT"],axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['LLS', 'MSFL', 'ITT'] not found in axis"

# %%
y=l1['RHOB']
X=l1.drop(['RHOB'],axis=1)

# %%
pd.plotting.scatter_matrix(l1,figsize=(20,10),diagonal='kde')
plt.show()

# %%
sns.boxplot(data=l1,x=l1['RHOB'])
plt.grid()
plt.xlim([2.132,2.7])
# Out:
# (2.132, 2.7)

# %%
l1=l1[l1['RHOB']<2.135]

# %%
l1
# Out:
#            DEPTH     CALI     ILD     LLD    NPHI    RHOB     SFL       SP
# 9587   1552.3464  14.7336  0.8370  0.8558  0.4351  2.1287  1.0228  39.0414
# 9591   1552.9560  14.5029  0.7855  0.8201  0.4108  2.1312  1.0096  38.7747
# 9592   1553.1084  14.0018  0.7886  0.8234  0.4104  2.1192  1.0205  39.4978
# 9593   1553.2608  13.8056  0.8528  0.8294  0.4278  2.1118  1.0322  39.9276
# 9594   1553.4132  13.9337  0.9196  0.8388  0.4451  2.1126  1.0386  40.0161
# ...          ...      ...     ...     ...     ...     ...     ...      ...
# 22942  3587.6484  12.4632  3.3798  2.8295  0.2346  1.7818  3.4092   8.1459
# 22943  3587.8008  12.6305  3.4585  2.8695  0.2415  1.7506  3.4267   7.9921
# 22944  3587.9532  11.9737  3.4617  2.9924  0.2526  1.8012  3.5028   7.6317
# 22945  3588.1056  12.1092  3.2860  3.1129  0.2644  1.8939  3.5125   7.6770
# 22946  3588.2580  12.2409  2.8994  3.1607  0.2483  2.0691  3.5382   8.4587
#
# [399 rows x 8 columns]

# %%
y=l1['RHOB']
X=l1.drop(['RHOB'],axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.33307240380093206

# %%
lr.score(X_test,y_test)
# Out:
# 0.25104148085367706

# %%
random_state=[x for x in range(200)]
mse_test=[]
mse_train=[]
train_score=[]
test_score=[]
for i in random_state:
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler()
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=i)
    X_train=scaler.fit_transform(X_train)
    X_test=scaler.transform(X_test)
    from sklearn.linear_model import LinearRegression
    lr=LinearRegression()
    lr.fit(X_train,y_train)
    from sklearn.metrics import mean_squared_error
    train_score.append(lr.score(X_train,y_train))
    test_score.append(lr.score(X_test,y_test))
    mse_train.append(mean_squared_error(y_train,lr.predict(X_train)))
    mse_test.append(mean_squared_error(y_test,lr.predict(X_test)))

# %%
mse_train
# Out:
# [0.003953354932911722,
#  0.003637847943816054,
#  0.003924007673239547,
#  0.0038024355138659583,
#  0.004069299687858117,
#  0.004098228212392762,
#  0.0035878421105485178,
